# %%
# Load data - Explore the smaller October dataset
df_oct = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv", header=True, inferSchema=True)

# %%
df_oct.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/ecommerce/ecommerce_data/df_oct_delta_day_5")

# %%
df_oct.write.format("delta").saveAsTable("df_oct_table_day_5_table")

# %% [markdown]
# #### MERGE = Upsert: update existing rows, insert new ones

# %%
# Inspect columns in the main table

spark.table("df_oct_table_day_5_table").printSchema()
# Out:
# root
#  |-- event_time: timestamp (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- user_id: integer (nullable = true)
#  |-- user_session: string (nullable = true)

# %%
from delta.tables import DeltaTable

# Load the main Delta table
delta_table = DeltaTable.forName(spark, "df_oct_table_day_5_table")

# Sample data for updates/inserts
updates = [
    ("2025-01-01 10:00:00", "purchase", 999999, 8888888888888, "cat.test", "brandZ", 99.99, 111111, "session111"),
    ("2025-01-01 11:00:00", "cart",     555555, 7777777777777, "cat.new",  "brandY", 49.49, 222222, "session222")
]

columns = ["event_time","event_type","product_id","category_id",
           "category_code","brand","price","user_id","user_session"]

df_updates = spark.createDataFrame(updates, schema=columns)

# Perform the merge using user_id as the match key
delta_table.alias("tgt").merge(
    df_updates.alias("src"),
    "tgt.user_id = src.user_id"
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %% [markdown]
# Check the different versions of our Delta table

# %%
# %sql
DESCRIBE HISTORY df_oct_table_day_5_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>1</td><td>2026-01-14T15:27:46.000Z</td><td>74403994742972</td><td>maisondemaitre+databricks@hotmail.com</td><td>MERGE</td><td>Map(predicate -> ["(cast(user_id#13810 as bigint) = user_id#13855L)"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> true, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(2719560714653473)</td><td>0114-151445-n91pfkwy-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 4816, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 3186, materializeSourceTimeMs -> 175, numTargetRowsInserted -> 2, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 1508, numTargetRowsUpdated -> 0, numOutputRows -> 2, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 2, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1357)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>0</td><td>2026-01-14T15:16:32.000Z</td><td>74403994742972</td><td>maisondemaitre+databricks@hotmail.com</td><td>CREATE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(2719560714653473)</td><td>0114-151445-n91pfkwy-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 43, numOutputRows -> 42448764, numOutputBytes -> 727560588)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>

# %% [markdown]
# Display the first 5 rows from version 1 (new version after MERGE) of the table.

# %%
# %sql
SELECT *
FROM df_oct_table_day_5_table
VERSION AS OF 1
LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_time</th><th>event_type</th><th>product_id</th><th>category_id</th><th>category_code</th><th>brand</th><th>price</th><th>user_id</th><th>user_session</th></tr></thead><tbody><tr><td>2019-10-19T06:15:06.000Z</td><td>view</td><td>49300013</td><td>2125931803410694331</td><td>null</td><td>weekend</td><td>875.18</td><td>515837919</td><td>0df7d269-da26-4087-b593-faee853ab0b5</td></tr><tr><td>2019-10-19T06:15:06.000Z</td><td>view</td><td>12706258</td><td>2053013553559896355</td><td>null</td><td>nokian</td><td>60.23</td><td>537960539</td><td>472c6bd5-6e1f-437f-aa84-a112885fefe2</td></tr><tr><td>2019-10-19T06:15:06.000Z</td><td>view</td><td>4804056</td><td>2053013554658804075</td><td>electronics.audio.headphone</td><td>apple</td><td>160.62</td><td>561794333</td><td>12a4b25d-21e7-4530-92f5-9f8d633b130b</td></tr><tr><td>2019-10-19T06:15:06.000Z</td><td>view</td><td>1004903</td><td>2053013555631882655</td><td>electronics.smartphone</td><td>huawei</td><td>111.7</td><td>553521751</td><td>9ad39586-648d-4b2d-932e-ec25acaed778</td></tr><tr><td>2019-10-19T06:15:06.000Z</td><td>view</td><td>1004587</td><td>2053013555631882655</td><td>electronics.smartphone</td><td>inoi</td><td>61.49</td><td>553442516</td><td>bad9e161-d7fe-4136-be2d-ccfba436b721</td></tr></tbody></table></div>

# %% [markdown]
# Compare record counts in historical as well as new version

# %%
# %sql

SELECT COUNT(*) AS historical_count
FROM df_oct_table_day_5_table
VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>historical_count</th></tr></thead><tbody><tr><td>42448764</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS current_count
FROM df_oct_table_day_5_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_count</th></tr></thead><tbody><tr><td>42448766</td></tr></tbody></table></div>

# %% [markdown]
# Run this to OPTIMIZE the whole table

# %%
# %sql
OPTIMIZE df_oct_table_day_5_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(14, 45, List(50909022, 55969823, 5.205239414285714E7, 14, 728733518), List(2395, 17695971, 1.616812008888889E7, 45, 727565404), 0, null, null, 0, 1, 45, 0, true, 0, 0, 1768405045891, 1768405054955, 8, 14, null, List(0, 0), null, 9, 9, 38870, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# VACCUM in action - Uses default retention period of 7 days. Deletes anything older.

# %%
# %sql
VACUUM df_oct_table_day_5_table RETAIN 168 HOURS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>
