# %% [markdown]
# #### Day 8

# %%
# %sql
-- Create a catalog (sort of like a domain boundary)
CREATE CATALOG IF NOT EXISTS ecommerce_catalog;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Use the catalog
USE CATALOG ecommerce_catalog;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Create Schemas (Bronze, Silver, Gold) - Mirroring the medallion architecture

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Verify if schemas have been created

SHOW SCHEMAS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>bronze</td></tr><tr><td>default</td></tr><tr><td>gold</td></tr><tr><td>information_schema</td></tr><tr><td>silver</td></tr></tbody></table></div>

# %%
# %sql
SHOW CATALOGS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>ecommerce_catalog</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr><tr><td>workspace</td></tr></tbody></table></div>

# %%
# %sql
-- List folders under this volume

SHOW VOLUMES IN workspace.ecommerce;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>ecommerce</td><td>ecommerce_data</td></tr></tbody></table></div>

# %%
# %sql
-- Explore the volume path

LIST '/Volumes/workspace/ecommerce/ecommerce_data';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modification_time</th></tr></thead><tbody><tr><td>/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv</td><td>2019-Nov.csv</td><td>9006762395</td><td>1767973029000</td></tr><tr><td>/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv</td><td>2019-Oct.csv</td><td>5668612855</td><td>1767973179000</td></tr><tr><td>/Volumes/workspace/ecommerce/ecommerce_data/df_oct_delta/</td><td>df_oct_delta/</td><td>0</td><td>1768673000920</td></tr><tr><td>/Volumes/workspace/ecommerce/ecommerce_data/df_oct_delta_day_5/</td><td>df_oct_delta_day_5/</td><td>0</td><td>1768673000920</td></tr><tr><td>/Volumes/workspace/ecommerce/ecommerce_data/df_oct_delta_day_6/</td><td>df_oct_delta_day_6/</td><td>0</td><td>1768673000920</td></tr></tbody></table></div>

# %% [markdown]
# Use catalogs & schema

# %%
# %sql
USE CATALOG ecommerce_catalog;
USE SCHEMA bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Create Tables by Writing Data - First Bronze

# %%
df_oct = spark.read.csv(
    "/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv",
    header=True,
    inferSchema=True
)

df_oct.write \
  .format("delta") \
  .mode("overwrite") \
  .saveAsTable("ecommerce_catalog.bronze.events")

# %% [markdown]
# Follow the same procedure for Silver & Gold

# %%
from pyspark.sql.functions import col

# ==========================
# 1) Read Bronze table
# ==========================
df_bronze = spark.table("ecommerce_catalog.bronze.events")

# ==========================
# 2) Clean & Validate Data
# (same as Day 6)
# ==========================
df_silver = df_bronze.filter(
    (col("event_time").isNotNull()) &
    (col("event_type").isNotNull()) &
    (col("user_id").isNotNull())
)

# Fill null text fields
df_silver = df_silver.na.fill({
    "brand": "Not_Available",
    "category_code": "Not_Available"
})

# ==========================
# 3) Drop Duplicates
# ==========================
df_silver = df_silver.dropDuplicates(["user_session", "event_time"])

# ==========================
# 4) Write Silver table
# ==========================
df_silver.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_catalog.silver.events")

# %% [markdown]
# Follow the same process for Gold

# %%
from pyspark.sql import functions as F

# ==========================
# 1) Read Silver table
# ==========================
silver = spark.table("ecommerce_catalog.silver.events")

# ==========================
# 2) Aggregate by category
# (same as Day 6)
# ==========================
category_perf = silver.groupBy("category_code") \
    .agg(
        F.countDistinct(
            F.when(F.col("event_type") == "view", F.col("user_session"))
        ).alias("unique_views"),

        F.countDistinct(
            F.when(F.col("event_type") == "cart", F.col("user_session"))
        ).alias("unique_carts"),

        F.countDistinct(
            F.when(F.col("event_type") == "purchase", F.col("user_session"))
        ).alias("unique_purchases"),

        F.sum(
            F.when(F.col("event_type") == "purchase", F.col("price"))
        ).alias("total_revenue")
    ) \
    .withColumn(
        "cart_to_purchase_ratio",
        F.when(
            F.col("unique_carts") > 0,
            F.round(F.col("unique_purchases") / F.col("unique_carts") * 100, 2)
        ).otherwise(0)
    )

# ==========================
# 3) Write Gold table
# ==========================
category_perf.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_catalog.gold.category_performance")

# %% [markdown]
# Check if your data tables are inside your catalog/schemas
#
# We did this using:
# .saveAsTable("ecommerce_catalog.bronze.events")
# .saveAsTable("ecommerce_catalog.silver.events")
# .saveAsTable("ecommerce_catalog.gold.category_performance")
#
# Just check this-

# %%
# %sql
SHOW TABLES IN ecommerce_catalog.bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>bronze</td><td>events</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SHOW TABLES IN ecommerce_catalog.silver;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>silver</td><td>events</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SHOW TABLES IN ecommerce_catalog.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>gold</td><td>category_performance</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# Set Up Permissions

# %% [markdown]
# Example: Read-only access to _Silver_ for me

# %% [markdown]
# Identify current user

# %%
# %sql
SELECT current_user();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_user()</th></tr></thead><tbody><tr><td>maisondemaitre+databricks@hotmail.com</td></tr></tbody></table></div>

# %%
# %sql
GRANT SELECT
ON SCHEMA ecommerce_catalog.silver
TO `maisondemaitre+databricks@hotmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Grant Gold read-only access to me

# %%
# %sql
GRANT SELECT
ON SCHEMA ecommerce_catalog.gold
TO `maisondemaitre+databricks@hotmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Create Views for Controlled Access (hide raw columns)

# %%
# %sql
CREATE OR REPLACE VIEW ecommerce_catalog.gold.v_category_summary AS
SELECT
    category_code,
    unique_purchases,
    total_revenue,
    cart_to_purchase_ratio
FROM ecommerce_catalog.gold.category_performance;

# %% [markdown]
# Grant access to view only - for this particular table

# %%
# %sql
GRANT SELECT
ON VIEW ecommerce_catalog.gold.v_category_summary
TO `maisondemaitre+databricks@hotmail.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
